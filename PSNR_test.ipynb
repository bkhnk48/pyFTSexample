# %%
from math import log10, sqrt
import cv2
import numpy as np

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0):  # MSE is zero means no noise is present in the signal .
                  # Therefore PSNR have no importance.
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

def main():
     original = cv2.imread("original_image.png")
     compressed = cv2.imread("compressed_image.png", 1)
     value = PSNR(original, compressed)
     print(f"PSNR value is {value} dB")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-819263a094c9> in <cell line: 20>()
#      19
#      20 if __name__ == "__main__":
# ---> 21     main()
#
# <ipython-input-1-819263a094c9> in main()
#      15      original = cv2.imread("original_image.png")
#      16      compressed = cv2.imread("compressed_image.png", 1)
# ---> 17      value = PSNR(original, compressed)
#      18      print(f"PSNR value is {value} dB")
#      19
#
# <ipython-input-1-819263a094c9> in PSNR(original, compressed)
#       4
#       5 def PSNR(original, compressed):
# ----> 6     mse = np.mean((original - compressed) ** 2)
#       7     if(mse == 0):  # MSE is zero means no noise is present in the signal .
#       8                   # Therefore PSNR have no importance.
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'NoneType'
